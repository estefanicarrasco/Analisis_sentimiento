# %%
import streamlit as st
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(20, 3), columns = ["a", "b", "c"])

# %%
df
# Out:
#            a         b         c
# 0   0.531200 -0.783168  0.838444
# 1   1.297379 -0.207220 -0.322568
# 2   0.360558 -0.082869 -1.483875
# 3   0.923884  0.393282 -0.830426
# 4  -0.979699 -0.271188  0.596198
# 5   0.252742  0.207092  1.125649
# 6   0.830937  0.366793 -0.316980
# 7  -0.907383 -1.373584 -1.610708
# 8   1.455308  1.544460 -1.356909
# 9  -0.523807  0.524346 -0.974485
# 10  0.106982  0.277646 -0.138820
# 11  0.238289 -0.255682 -1.534827
# 12  0.306289  0.786231  0.407146
# 13 -0.106424 -0.124283 -0.512061
# 14  0.175355 -0.943184 -0.661418
# 15  0.747475 -0.878234 -1.573761
# 16 -0.090758  1.171407 -0.680259
# 17 -1.159591 -1.043124 -0.265016
# 18 -0.449662  0.440094 -1.148649
# 19 -1.751789  0.429377 -0.793923
